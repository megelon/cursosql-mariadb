# %% [markdown]
# # Módulo 1: Antes de empezar

# %% [markdown]
# # Clase 1: Por qué deberías tomar este curso conmigo e introducción al proyecto final
#
# ## Guion:
#
# - ¡Hola bienvenido a este curso! Mi nombre es Miguel y tengo el gusto de compartir mi experiencia contigo.
# - En esta clase te voy a contar un poco sobre mí.
# - Soy Bogotano, tengo 27 años, me apasiona hacer kitesurfing, viajar y reciclar.
# - Además me encanta compartir conocimiento y crear comunidad, por eso me encantó la idea de diseñar este curso.
# - Compartire mis más de 5 años de experiencia trabajando como Científico de Datos.
# - Para todo tipo de compañías, grandes, medianas, chicas, en crecimiento acelerado.
# - Enfrentado todo tipo de necesidades.
# - he descubierto el valor de la explotación de datos.
# - y he visto que es altamente valorada por todos los niveles jerárquicos de una organización
# - esto me ha dado una ventaja competitiva
# - y me ha abierto muchas oportunidades en el mercado laboral.
#
#
# - Mi sueño es que latinoamerica sea una región cada vez más interesante para la inversión extranjera.
# - Para ello necesitamos acelerar el desarrollo de personas como tú y yo, que aprendan y luego compartan con otros.
#
#
# - Quiero que personas como tú aceleren su carrera.
# - Y para ello te voy a enseñar los fundamentos del DS.
# - Poco a poco te volverás experto en agregar valor al negocio.
# - Entenderás qué necesita, cuándo lo necesita y por qué lo necesita.
#
#
#
# - He trabajado con múltiples motores y clientes de bases de datos,
# - Si no tienes claro que es un motor o cliente de base de datos no te preocupes en este curso lo entenderás con facilidad.
# - Yo trabajé en consultoría y me tocó aprender a trabajar con varios MySQL, MariaDB, MongoDB, Postgresql, Bigquery, Snowflake, SAS, R, Python, entre otros.
# - Al final hay que adaptarse siempre a las necesidades del cliente, sin embargo esto no ha sido un problema para mí, la estructura básica será siempre similar.
# - Te darás cuenta que una vez entiendas la estructura básica y funcionamiento de al menos uno de los motores de bases de datos que existen en el mercado, serás capáz de moverte fácilmente entre cualquiera sin ningún problema.
#
# - He participado y liderado proyectos de todo el ciclo de vida de los datos, desde la captura y almacenamiento, la validación de calidad, la creación de tableros,
# - hasta proyectos dónde usando machine learning e inteligencia artificial resuelvo problemas de negocio.
#
#
# Ahora disfruta al máximo lo bonito que es aprender.
#
# ### Antes que nada, les contare el proyecto que iremos desarrollando durante el curso.
#
# El objetivo del proyecto final es que..
# seas capaz de abordar un problema de analytics desde cero y apliques las herramientas que vas a aprender durante el curso, para resolver este problema.
#
# Ahora hablemos de los avances ..
# El proyecto final de este curso consiste en asumir el rol de Business Intelligence Analyst, para una compañía de Sillicon Valley. El board de la compañía te contrató para crear un tablero de indicadores que los ayude a tomar mejores decisiones. Para lograrlo vamos a:
# 1. definir y ejecutar una metodologia de trabajo,
# 2. instalaremos las herramientas necesarias y
# 3. finalmente construiremos el tablero usando SQL en el proceso.
#
# Para realizar este proyecto vamos a necesitar..
# 1. Una base de datos
# 2. Un motor de base de datos
# 3. Un cliente de base de datos.
#
# No te preocupes si te sientes un poco perdido con esta lista de cosas, mas adelante vamos a ver en detalle para que se utiliza cada una e incluso el proceso para obtenerlas. Todas se pueden descargar de forma gratuita de internet y no te tomará demasiado tiempo instalarlas.
#
# Terminando este curso podrás agregar valor a cualquier compañía que valore que sus empleados sepan SQL y además conozcan metodologías para trabajar con datos. Serás alguien orientado al negocio y con una ventaja competitiva sobre el resto ya que tendrás acceso directo a los datos y así podrás construir argumentos sólidos en poco tiempo.
#
# ¿Listos para comenzar? ¡Empecemos!

# %% [markdown]
# # Clase 2: ¿Por qué es valioso para tí tomar un curso sobre SQL? Pregunta central + Problemática del curso
#
# ## Guion:
# Antes de continuar, hablemos sobre por qué es valioso para tí tomar un curso de SQL.
#
# Desde la creación del internet, el acceso a la información se ha reinventado. Ahora podemos tomar MOCS en línea, hablar con personas que están al otro lado del mundo con tan sólo un click y resolver cualquier inquietud que tengamos con una simple consulta a los servidores de google; cuyo éxito también ha estado en la forma en cómo han disponibilizado la información para que podamos acceder a ella justo en el momento en el que la necesitamos.
#
# Por la forma cómo empresas cómo Google, Amazon y Facebook han tendio éxito es que hoy es tan popular y necesario saber de herramientas como SQL. Amazon arrancó en el boom del internet comercializando libros, Facebook, compartiendo fotos. Las tres compañías son compañías digitales que requirieron desde sus inicios almacenar información bien sea de sus usuarios, sus productos o servicios.
#
# Los datos siempre fueron el eje central del negocio. Sin datos Google no tendría necesidad de desarrollar un algorítmo de optimización de busqueda cómo page rank, para ofrecer la página adecuada de acuerdo a lo que está buscando el usuario. Amazon no contaría con un inventario de libros disponible en internet y Facebook no tendría fotos que mostrar. Todos estos negocios han sido construidos sobre datos, han madurado y ahora cuentan con volúmenes de datos que les han creado la necesidad de ser capaces de analizarlos para agregar más valor al negocio Así han entrado a utilizar analítica avanzada y machine lerning para tomar mejores decisiones.
#
# Veámos un ejemplo del reto al que se enfrentan estas compañías.. Juan trabaja en una compañia en Silicon Valley y necesita resumir toda la infomación que tiene disponible, para así tomar la mejor decisión. Utilizará un modelo de aprendizaje de maquina que le permite sintetizar información y traducirla en un si o un no. Él tendrá que dedicar el 80% del tiempo trabajando los datos para que el algoritmo que usa el modelo funcione y arroje los mejores resultados.

# %%
from IPython.display import Image
Image("../Images/caso_uso_0.png")

# %%
Image("../Images/caso_uso_1.png")

# %% [markdown]
# Luego de esta contextualización,
#
# La pregunta central de este curso es ¿SQL o SQL orientado al negocio? / ¿Para que aprender SQL y como aplicarlo al negocio?
#
# La información siempre ha sido necesaria para tomar decisiones. Un emprendedor necesita saber qué necesita el consumidor. Un consumidor necesita saber cúal es la mejor oferta. Un juez necesita pruebas para condenar o absolver a alguien. Un periodista necesita una fuente para escribir un artículo.
# Hay muchos ejemplos.
#
# Todos necesitamos tomar decisiones y cuando llega el momento queremos tomar la mejor. Cada día tenemos acceso a más información pero no necesariamente somos capaces de acceder a ella cuando la necesitamos, ni mucho menos procesarla oportunamente. Debemos ser capaces de utilizar los recursos que tengamos a la mano para empezar a recolectar información que creamos útil y a la que luego podamos acceder rápidamente para tomar una decisión que al final nos lleve al resultado esperado.
#
# La información se convierte en un activo valioso, únicamente si al momento en el que la necesitamos, disponemos de ella.
# Piénsa en la información cómo un paracaídas, adquiere valor sí lo tenemos disponible en el momento oportuno, de lo contrario no sirve para nada.
#
# Nunca será suficiente con tener los datos, tener la herramienta más cara para explotarlos, inclusive conocer las técnicas más sofisticadas para sacar provecho de ellos, si al final no tenemos la capacidad de poner la información a disposición de quien debe tomar la decisión, de tal forma que la pueda interpretar correctamente, de forma rápida para tomar la mejor decisión.
#
# De esto se trata este curso.
# De desarrollar capacidades técnicas, que nos conviertan en profesionales ágiles para consultar información.
# Un profesional ágil es alguien que sabe:
# - dónde están los datos,
# - cómo acceder a ellos,
# - tiene habilidades para resolver problemas de negocio.
# - moldea soluciones según el contexto.
#
# Es por eso que este curso tiene dos enfoques.
# - SQL: Ejercicios prácticos para que desarrolles tus habilidades de consulta a las bases de datos.
# - NEGOCIO: Ejercicios prácticos para que desarrolles tus habilidades para resolver problemas de negocio.
#
# Ahora que ya cubrimos la base, ¡te veo en la siguiente clase!

# %%
#!jupyter nbconvert --to html _Modulo_1_intro1.ipynb
#!jupyter nbconvert --to html _Modulo_1_intro1.ipynb
