# %%
from IPython.display import Image
path="../images/"

# %% [markdown]
# # Módulo 6. Manos a la obra!
#
# ## Clase 40. Primeros pasos.
#
# ¡Hola! Llegó la hora de ponernos a practicar comandos de SQL.  En este módulo te enfrentarás a ejercicios prácticos, en una herramienta diseñada para poner en práctica tus conocimientos, tendrás un reto, la oportunidad de solucionarlo usando una sentencia de SQL y sabrás si el resultado fue el esperado o no.
#
# *** -------------¿Estas acostumbrado a tomar la lección en grupo y luego hacer la tarea sólo? Acá vamos a darle la vuelta a esa situación... Si no lo logras me tienes a mí y además a tus compañeros de clase, con quienes podrás compartir enfoques diferentes para solucionar los problemas. Usaremos espacios de colaboración para ayudarnos entre todos y ¡Aprender!
#
# *** Stackoverflow
#
# *** Documentación de MySQL / MariaDB
#
# *** Quora
#
# . ------------------Tienes la percepción que solucionar este tipo de problemas es para pocos, pues no, es para todos...
#
# La plataforma en dónde vamos a trabajar este módulo es https://www.hackerrank.com/.
# - El primer paso es abrir una cuenta.
# - - Para abrir una cuenta en hackerrank los pasos son los siguientes:

# %% [markdown]
# - - -    Ingresas a la página das click en "Sign Up & Code":

# %%
Image(path+'HAKERRANK1.jpg') # 1-6

# %% [markdown]
# - - - Ingresas tu nombre, email y contraseña:

# %%
Image(path+'HAKERRANK2.jpg') # 1-6

# %% [markdown]
# - - - Escojes el lenguaje de programación que quieres practicar, en este caso SQL:

# %%
Image(path+'HAKERRANK3.jpg') # 1-6

# %% [markdown]
# - - - Seleccionas un desafío. Vamos a empezar por los de dificultad "fácil", el subdomino "Basic Select", el desafío "Select All"

# %%
Image(path+'HAKERRANK5.jpg') # 1-6

# %%
Image(path+'HAKERRANK6.jpg') # 1-6

# %% [markdown]
# Nuestro primer desafío es seleccionar todos los atributos para cada fila en la tabla city.
# - la solución... te la diré * EN EL SIGUIENTE VIDEO*
#
# Por ahora exploremos la herramienta,
# - ### Problem, es dónde tienes la descripción del reto y el campo para enviar el código.
# - - Un detalle interesante es que tienes la opción de enviar el desafío usando varios motores de bases de datos
# - - - DB2: Es un sistema de gestión de bases de datos relacional, propiedad de IBM.
# - - - MySQL: Es un sistema de gestión de bases de datos relacional propiedad de Oracle Corporation. Es la base de datos de código abierto más popular del mundo y una de las más populares en general junto a Oracle Database y Microsoft SQL Server. Es el padre de MariaDB un sistema de gestión de bases de datos derivado de MySQL con licencia pública general.
# - - - Oracle: Oracle Database es un sistema de gestión de base de datos de tipo objeto-relacional, desarrollado por Oracle Corporation. Líder en el mercado de servidores empresariales hasta que entró a competir con Microsoft SQL Server, PostgreSQL, MySQL y Firebird.
# - - - MS SQL Server: Microsoft SQL Server es un sistema de gestión de base de datos relacional, desarrollado por la empresa Microsoft.
#
# En el proyecto final usaremos MySQL o MaríaDB, así que te recomiendo resolver los desafíos usando MySQL como motor de bases de datos.
#
# - Submissions, es dónde podrás ver tu historial de envíos de código, si fue aceptado exitosamente, el puntaje, lenguaje, hace cuánto lo enviaste y los resultados de los casos de prueba.
# - Leaderboard, es dónde podrás comparar tu desempeño versus el del resto de usuarios que han enviado soluciones al reto y podrás consultar sus soluciones.
# - Discussions, es dónde podrás escribir tus preguntas, consultar si es que alguien más ya hizo la misma pregunta o ayudarle a alguien a resolver alguna duda.
# - Editorial, es dónde podrás consultar la documentación del reto, quién lo subio y lo probó, generlamente encontrarás la solución acá.
#
# ¡Estamos listos! ¡Ya nos vemos!

# %% [markdown]
# ## Clase 41
#
# Hola! La clase pasada aprendimos sobre Hackerrank y vimos que habian muchos ejercicios.
# Vamos a empezar por solucionar Select All y Select by ID. Cada vez se pondran mas interesantes los retos. Asi que empecemos.
#
# #### Select All
# Nuestro primer desafío es seleccionar TODOS los atributos para cada fila en la tabla city.
# - la solución vamos a enviarla en las cuatro variaciones de SQL, queremos ver que diferencias hay en cada una.
#
# 1. DB2: SELECT * FROM CITY; si no ponemos el ";" vamos a obtener error.
# 2. MySQL: SELECT * FROM CITY
# 3. Oracle: SELECT * FROM CITY;
# 4. MS SQL SERVER: SELECT * FROM CITY;
#
# Ahora podemos ir a submissions, ver el historial de envíos que hemos hecho.
# Revisar la tabla de posiciones
# Hacer un comentario en discussions
# Y ver el editorial, conectémonos con esta persona, puede que más adelante nos interese hablar más con ella.
#
# Ahora vamos por el siguiente desafío, en el que debemos seleccionar todos los atributos pero agregando un filtro. Para esto usaremos el comando Where al final de la sentencia.
#
# #### Select by ID,
#
# - la solución vamos a enviarla en las cuatro variaciones de SQL.
#
# 1. DB2: select * from city where id=1661; es indispensable terminar con ;
# 2. MySQL: select * from city where id=1661 NO es indispensable terminar con ;
# 3. Oracle: select * from city where id=1661; es indispensable terminar con ;
# 4. MS SQL SERVER: select * from city where id=1661; es indispensable terminar con ;
#
# Este es un ejemplo fácil en el que la variable a filtrar es numérica. Mas adelante veremos como se debe hacer cuando la variable esté en formato texto o fecha.

# %% [markdown]
# ## Clase 42
# En esta clase vamos a avanzar en la solución de varios ejercicios del subdominio Basic Select de Hackerrank. Veremos algunas precisiones adicionales de los comandos select y where que ya vimos, y utilizaremos el comando and.
#
# #### Japanese cities atributes
# En este ejercicio debemos filtrar una variable que no es numérica sino de tipo texto. Más adelante veremos la funcionalidad que nos sirve para conocer el formato de cada variable y así no fallar en los filtros.
# La solución de este ejercicio es:
# - select * from city where countrycode='JPN'
#
# #### Japanese cities names
# En este ejercicio no queremos seleccionar TODAS las variables, sino solo una y adicionalmente debemos hacer un filtro. Para seleccionar una variable específica, no escribimos Select *, sino que escribimos  Select y en seguida el nombre de la variable que queremos seleccionar.
# La solución de este ejercicio es:
# - select NAME from city where countrycode='JPN'
#
# #### Revising the Select Query I
# En este ejercicio vamos a seleccionar todas las variables, pero vamos a hacer mas de un filtro. Para esto usaremos los comandos where para el primer filtro y and para los filtros adicionales.
# La solución de este ejercicio es:
# - select * from city where countrycode='USA' and population >= 100000
#
# #### Revising the Select Query II
# En este ejercicio debemos seleccionar una variable específica y hacer dos filtros. Para esto aplicamos lo que aprendimos en los ejercicios anteriores.
# La solución de este ejercicio es:
# - select name from city where population > 120000 and countrycode='USA'
#
#
# #### Weather Observation Station 1
# Para terminar haremos un ejercicio que incorpora mas de una variable a la selección. Para esto usamos el comando Select y simplemente separamos los nombres de las variables con comas. Podemos incluir todas las variables que deseemos siguiendo esta estructura: Select variable1, variable2, variable3, variableN from. Recuerda que no debes poner coma despues de la última variable a seleccionar.
# - select CITY, STATE from station
#
#
# ## Clase 43
# Hola! El objetivo de esta clase, es aprender sobre los comandos sum, round, modulo y distinct. Para ellos resolveremos algunos ejercicios adicionales del subdominio Basic Select de Hackerrank. Veamos:
#
# .-------------------------
# #### Weather Observation Station 2
# Para este ejercicio nos piden obtener la sumatoria de dos variables y redondear los resultados con dos decimales.
# Para la sumatoria usaremos el comando SUM y entre parentesis la variable a ser sumada.
# Para redondear usaremos el comando ROUND de la siguiente forma: ROUND (número a ser redondeado que en este caso es la sumatoria de una variable , número de decimales ).
# La senetencia se debe construir guardando el mismo orden lógico que hemos visto hasta ahora: Select variable1 (que en este caso es la sumatoria redondeada de una variable) , variable2 (que en este caso es la sumatoria redondeada de otra variable) from la tabla fuente.
# La solución de este ejercicio es:
# - SELECT ROUND(SUM(LAT_N),2), ROUND(SUM(LONG_W),2) FROM STATION
#
# #### Weather Observation Station 3
# - select distinct city from station where id%2=0 group by city
#
# #### Weather Observation Station 4
# - select count(CITY) - count(distinct(CITY)) from STATION
#
# ####  Weather Observation Station 5
# - select
# city, length(city) as lenght
# from station
# group by city
# order by 2,1
# limit 1;
#
# - select * from (
# select
# city, length(city) as lenght
# from station
# group by city
# order by 2,1
# ) a
# order by lenght desc
# limit 1
# ;
#
# .---------------------------------
# #### Weather Observation Station 6
# - select distinct city from (
# select
# city,
# left(city,1) as var1
# from station
# ) a
# where var1 in ('a','e','i','o','u','A','E','I','O','U')
# ;
#
# #### Weather Observation Station 7
#
# - select distinct city
# from
# (
# select
# city,
# right(city,1) as var2
# from station
# ) a
# where var2 in ('a','e','i','o','u','A','E','I','O','U')
#
# #### Weather Observation Station 8
#
# - select distinct city from ( select city, left(city,1) as var1,right(city,1) as var2 from station ) a where var1 in ('a','e','i','o','u','A','E','I','O','U')
# and var2 in ('a','e','i','o','u','A','E','I','O','U')
#
# #### Weather Observation Station 9
#
# - select distinct city from ( select city, left(city,1) as var1 from station ) a where var1 not in ('a','e','i','o','u','A','E','I','O','U')
#
# #### Weather Observation Station 10
#
# - select distinct city from ( select city, right(city,1) as var1 from station ) a where var1 not in ('a','e','i','o','u','A','E','I','O','U')
#
# #### Weather Observation Station 11
#
# - select distinct city from ( select city, lower(left(city,1)) as var1,lower(right(city,1)) as var2 from station ) a where var1 not in ('a','e','i','o','u')
# or var2 not in ('a','e','i','o','u')
#
# #### Weather Observation Station 12
#
# - select distinct city from ( select city, lower(left(city,1)) as var1,lower(right(city,1)) as var2 from station ) a where var1 not in ('a','e','i','o','u')
# and var2 not in ('a','e','i','o','u')
#
# #### Weather Observation Station 13
#
# - select round(sum(lat_n),4) from station
# where lat_n > 38.7880
# and lat_n < 137.2345
#
# #### Weather Observation Station 14
#
# - select round(max(lat_n),4) from station
# where lat_n < 137.2345
#
# #### Weather Observation Station 15
#
# - select round(LONG_W, 4)
# from station
# where LAT_N < 137.2345
# order BY LAT_N DESC
# limit 1
#
# #### Weather Observation Station 16
#
# - select round(min(lat_n),4) from station
# where lat_n > 38.7780
#
# #### Weather Observation Station 17
#
# - select round(LONG_W, 4)
# from station
# where LAT_N > 38.7780
# order by LAT_N asc
# limit 1

# %% [markdown]
# # Clase 44
# ### Aggregations
# #### Revising Aggregations - The Count Function
# - select count(name) from city where population>100000
# - select count(*) from city where population>100000
#
# #### Revising Aggregations - The Sum Function
# - select sum(population) from city where district='California'
#
# #### Revising Aggregations - Averages
# - SELECT AVG(POPULATION) FROM CITY WHERE DISTRICT='California'
#
# #### Average Population
# - SELECT ROUND(AVG(POPULATION)) FROM CITY
#
# #### Japan Population
# - SELECT SUM(POPULATION) FROM CITY WHERE COUNTRYCODE='JPN'
#
# #### Population Density Difference
# - SELECT (SELECT MAX(POPULATION) FROM CITY) - (SELECT MIN(POPULATION) FROM CITY)

# %% [markdown]
# # Clase 45
# ### Joins
#
# #### Asian Population
# - SELECT SUM(CITY.POPULATION) FROM CITY LEFT JOIN COUNTRY ON CITY.CountryCode = COUNTRY.Code WHERE COUNTRY.CONTINENT = 'Asia'
#
# #### African Cities
# - SELECT CITY.NAME FROM CITY LEFT JOIN COUNTRY ON CITY.CountryCode = COUNTRY.Code WHERE COUNTRY.CONTINENT = 'Africa'
#
# #### Average Population of Each Continent
# - SELECT COUNTRY.Continent, FLOOR(AVG(CITY.Population)) FROM CITY INNER JOIN COUNTRY ON CITY.CountryCode = COUNTRY.Code GROUP BY COUNTRY.Continent

# %% [markdown]
# Ahora que terminaste todos, vamos al siguiente módulo!
