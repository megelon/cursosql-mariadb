# %%
from IPython.display import Image
path="../Images/"

# %% [markdown]
# Clases: Dbeaver intro...

# %% [markdown]
# # Clase 6. Herramientas, instalación fase 1. (DB)
#
# - Hola. Vamos a descargar los datos!
# - Ellos están en kaggle, puedes acceder a el con el siguiente link: https://www.kaggle.com/sirpunch/meetups-data-from-meetupcom.
# - Para poder descargarlos debes tener una cuenta,
# - si no tienes una puedes crearla con google ó con tu email.
# - Si tienes una lo único que debes hacer es acceder a ella y descargar!
# - Ya estuvo! Tenemos nuestro daset! Te recomiendo guardarlo todo en tu local, bien ordenado. Yo los guardaré en una carpeta llamada, "proyecto_ds_0".

# %%
i=1
Image("../Images/kaggle_"+str(i)+".png") # 1 - 9

# %% [markdown]
# # Clase 7. Herramientas, instalación fase 2. (Motor)
#
# - Hola. Vamos a descargar el servidor en dónde estará hosteado nuestro motor.
# - Puedes descargarlo acá: https://www.apachefriends.org/es/download.html.
# - Vamos a instalarlo!

# %%
i=11
Image(path+'XAMPP'+str(i)+'.jpg') # 1 - 14

# %% [markdown]
# # Clase 8. Herramientas, instalación fase 3. (Cliente)
#
# - Hola. Vamos a descargar nuestro cliente de base de datos.
# - Puedes descargarlo acá: https://dbeaver.io/download/
# - Ahora que lo descagargaste, vamos a instalarlo!

# %%
i=20
Image(path+'DBEAVER'+str(i)+'.jpg') # 1 - 20

# %% [markdown]
# # Conexión BASE DE DATOS Y CLIENTE.
#
# - Para conectar nuestro cliente con la base de datos.
# - Vamos primero a Xampp y prendemos nuestro servidor.
# - Una vez prendido, vamos a Dbeaver a hacer la conexión con MariaDB.
# - Sólo debemos buscar MariaDB y listo. Estamos conectados!

# %%
Image(path+'DBEAVER1.jpg')

# %%
Image(path+'DBEAVER2.jpg')

# %%
Image(path+'DBEAVER3.jpg')

# %%
Image(path+'DBEAVER4.jpg')

# %%
Image(path+'DBEAVER5.jpg')

# %%
Image(path+'DBEAVER6.jpg')

# %%
Image(path+'DBEAVER7.jpg')

# %%
Image(path+'DBEAVER8.jpg')

# %%
Image(path+'DBEAVER9.jpg')

# %%
Image(path+'DBEAVER10.jpg')

# %%
Image(path+'DBEAVER11.jpg')

# %%
Image(path+'DBEAVER12.jpg')

# %%
Image(path+'DBEAVER13.jpg')

# %%
Image(path+'DBEAVER14.jpg')

# %%
Image(path+'DBEAVER15.jpg')

# %%
Image(path+'DBEAVER16.jpg')

# %%
Image(path+'DBEAVER17.jpg')

# %%
Image(path+'DBEAVER18.jpg')

# %%
Image(path+'DBEAVER19.jpg')

# %%
Image(path+'DBEAVER20.jpg')

# %% [markdown]
# # XAMPP

# %%
Image(path+'XAMPP1.jpg')

# %%
Image(path+'XAMPP2.jpg')

# %%
Image(path+'XAMPP3.jpg')

# %%
Image(path+'XAMPP4.jpg')

# %%
Image(path+'XAMPP5.jpg')

# %%
Image(path+'XAMPP6.jpg')

# %%
Image(path+'XAMPP7.jpg')

# %%
Image(path+'XAMPP8.jpg')

# %%
Image(path+'XAMPP9.jpg')

# %%
Image(path+'XAMPP10.jpg')

# %%
Image(path+'XAMPP11.jpg')

# %%
Image(path+'XAMPP12.jpg')

# %%
Image(path+'XAMPP13.jpg')

# %%
Image(path+'XAMPP14.jpg')
